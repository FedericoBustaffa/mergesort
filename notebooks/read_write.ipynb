# %%
import pandas as pd

df = pd.read_csv("../results.csv")
df
# Out:
#       bufsize  chunksize     write      read
# 0  1073741824  134217728  0.354036  0.368218
# 1  1073741824  268435456  0.361825  0.362868
# 2  1073741824  536870912  0.360071  0.352390
# 3  2147483648  134217728  0.788031  0.784058
# 4  2147483648  268435456  0.793217  0.788944
# 5  2147483648  536870912  0.785559  0.778419
# 6  4294967296  134217728  1.653360  1.666380
# 7  4294967296  268435456  2.282690  2.269070
# 8  4294967296  536870912  2.273980  2.275010
